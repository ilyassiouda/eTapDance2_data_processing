# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 15}) # pour augmenter la taille de caractère dans les graphiques
largeur = 15
hauteur = 8

# %%
def feat_mean(label):
    feat_pos = [0,52,104,152,196,242]
    feat_mean_single = []
    feat_df = pd.read_csv('etapdance2/step_features_table_filt_truecorr_full_final.txt')
    feat_extr = np.array(feat_df[label])[1:].astype(float)
    for n in range(len(feat_pos)-1):
        pouet = feat_extr[feat_pos[n]:feat_pos[n+1]]/(feat_pos[n+1]-feat_pos[n])
        feat_mean_single = np.append(feat_mean_single, np.sum(pouet))
    return feat_mean_single

# %%
# comparaison gyro mean
single_labels = ["brush_back","brush_forward","dig","heel","step"]

plt.figure(figsize=(largeur,hauteur))
plt.plot(single_labels,feat_mean('Gyro0X mean'),label='Gyro0X mean')
plt.plot(single_labels,feat_mean('Gyro0Y mean'),label='Gyro0Y mean')
plt.plot(single_labels,feat_mean('Gyro0Z mean'),label='Gyro0Z mean')

plt.plot(single_labels,feat_mean('Gyro1X mean'),label='Gyro1X mean')
plt.plot(single_labels,feat_mean('Gyro1Y mean'),label='Gyro1Y mean')
plt.plot(single_labels,feat_mean('Gyro1Z mean'),label='Gyro1Z mean')
plt.ylabel('feature')
plt.xlabel('pas')
plt.autoscale(axis='x',tight=True);
plt.legend()
plt.show()

feat_mean('Gyro0X mean')
# Out:
# array([ 0.06032534,  0.00210882,  0.00025681,  0.00254143, -0.00860638])

# %%
#Comparaison accel mean
single_labels = ["brush_back","brush_forward","dig","heel","step"]

plt.figure(figsize=(largeur,hauteur))
plt.plot(single_labels,feat_mean('Accel0X mean'),label='Accel0X mean')
plt.plot(single_labels,feat_mean('Accel0Y mean'),label='Accel0Y mean')
plt.plot(single_labels,feat_mean('Accel0Z mean'),label='Accel0Z mean')

plt.plot(single_labels,feat_mean('Accel1X mean'),label='Accel1X mean')
plt.plot(single_labels,feat_mean('Accel1Y mean'),label='Accel1Y mean')
plt.plot(single_labels,feat_mean('Accel1Z mean'),label='Accel1Z mean')
plt.ylabel('feature')
plt.xlabel('pas')
plt.autoscale(axis='x',tight=True);
plt.legend()
plt.show()

# %%
# comparaison gyro std
single_labels = ["brush_back","brush_forward","dig","heel","step"]

plt.figure(figsize=(largeur,hauteur))
plt.plot(single_labels,feat_mean('Gyro0X std'),label='Gyro0X std')
plt.plot(single_labels,feat_mean('Gyro0Y std'),label='Gyro0Y std')
plt.plot(single_labels,feat_mean('Gyro0Z std'),label='Gyro0Z std')

plt.plot(single_labels,feat_mean('Gyro1X std'),label='Gyro1X std')
plt.plot(single_labels,feat_mean('Gyro1Y std'),label='Gyro1Y std')
plt.plot(single_labels,feat_mean('Gyro1Z std'),label='Gyro1Z std')
plt.ylabel('feature')
plt.xlabel('pas')
plt.autoscale(axis='x',tight=True);
plt.legend()
#plt.savefig(fname='couplage_AC_step.png')
plt.show()

# %%
#Comparaison accel std
single_labels = ["brush_back","brush_forward","dig","heel","step"]

plt.figure(figsize=(largeur,hauteur))
plt.plot(single_labels,feat_mean('Accel0X std'),label='Accel0X std')
plt.plot(single_labels,feat_mean('Accel0Y std'),label='Accel0Y std')
plt.plot(single_labels,feat_mean('Accel0Z std'),label='Accel0Z std')

plt.plot(single_labels,feat_mean('Accel1X std'),label='Accel1X std')
plt.plot(single_labels,feat_mean('Accel1Y std'),label='Accel1Y std')
plt.plot(single_labels,feat_mean('Accel1Z std'),label='Accel1Z std')
plt.ylabel('feature')
plt.xlabel('pas')
plt.autoscale(axis='x',tight=True);
plt.legend()
plt.show()

# %%
# comparaison gyro ent
single_labels = ["brush_back","brush_forward","dig","heel","step"]

plt.figure(figsize=(largeur,hauteur))
plt.plot(single_labels,feat_mean('Gyro0X ent'),label='Gyro0X ent')
plt.plot(single_labels,feat_mean('Gyro0Y ent'),label='Gyro0Y ent')
plt.plot(single_labels,feat_mean('Gyro0Z ent'),label='Gyro0Z ent')

plt.plot(single_labels,feat_mean('Gyro1X ent'),label='Gyro1X ent')
plt.plot(single_labels,feat_mean('Gyro1Y ent'),label='Gyro1Y ent')
plt.plot(single_labels,feat_mean('Gyro1Z ent'),label='Gyro1Z ent')
plt.ylabel('feature')
plt.xlabel('pas')
plt.autoscale(axis='x',tight=True);
plt.legend()
#plt.savefig(fname='couplage_AC_step.png')
plt.show()

# %%
#Comparaison accel ent
single_labels = ["brush_back","brush_forward","dig","heel","step"]

plt.figure(figsize=(largeur,hauteur))
plt.plot(single_labels,feat_mean('Accel0X ent'),label='Accel0X ent')
plt.plot(single_labels,feat_mean('Accel0Y ent'),label='Accel0Y ent')
plt.plot(single_labels,feat_mean('Accel0Z ent'),label='Accel0Z ent')

plt.plot(single_labels,feat_mean('Accel1X ent'),label='Accel1X ent')
plt.plot(single_labels,feat_mean('Accel1Y ent'),label='Accel1Y ent')
plt.plot(single_labels,feat_mean('Accel1Z ent'),label='Accel1Z ent')
plt.ylabel('feature')
plt.xlabel('pas')
plt.autoscale(axis='x',tight=True);
plt.legend()
plt.show()

# %%
# comparaison gyro corr
single_labels = ["brush_back","brush_forward","dig","heel","step"]

plt.figure(figsize=(largeur,hauteur))
plt.plot(single_labels,feat_mean('Gyro0X corr'),label='Gyro0X corr')
plt.plot(single_labels,feat_mean('Gyro0Y corr'),label='Gyro0Y corr')
plt.plot(single_labels,feat_mean('Gyro0Z corr'),label='Gyro0Z corr')

plt.plot(single_labels,feat_mean('Gyro1X corr'),label='Gyro1X corr')
plt.plot(single_labels,feat_mean('Gyro1Y corr'),label='Gyro1Y corr')
plt.plot(single_labels,feat_mean('Gyro1Z corr'),label='Gyro1Z corr')
plt.ylabel('feature')
plt.xlabel('pas')
plt.autoscale(axis='x',tight=True);
plt.legend()
#plt.savefig(fname='couplage_AC_step.png')
plt.show()

# %%
#Comparaison accel corr
single_labels = ["brush_back","brush_forward","dig","heel","step"]

plt.figure(figsize=(largeur,hauteur))
plt.plot(single_labels,feat_mean('Accel0X corr'),label='Accel0X corr')
plt.plot(single_labels,feat_mean('Accel0Y corr'),label='Accel0Y corr')
plt.plot(single_labels,feat_mean('Accel0Z corr'),label='Accel0Z corr')

plt.plot(single_labels,feat_mean('Accel1X corr'),label='Accel1X corr')
plt.plot(single_labels,feat_mean('Accel1Y corr'),label='Accel1Y corr')
plt.plot(single_labels,feat_mean('Accel1Z corr'),label='Accel1Z corr')
plt.ylabel('feature')
plt.xlabel('pas')
plt.autoscale(axis='x',tight=True);
plt.legend()
plt.show()
